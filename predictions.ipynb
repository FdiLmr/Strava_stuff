# %%
import pandas as pd

# %% [markdown]
# ### Reading data

# %%
df = pd.read_csv('data/my_activity_data=20241115233935.csv')
print('Dataframe Shape:', df.shape)
df.head()
# Out:
# Dataframe Shape: (335, 60)
#    resource_state                                      name  distance  \
# 0               2                                    Volume   10723.9
# 1               2  Entraînement aux poids dans l'après-midi       0.0
# 2               2                                    Volume   10277.0
# 3               2  Entraînement aux poids dans l'après-midi       0.0
# 4               2                           Volume + 4*1000   15696.7
#
#    moving_time  elapsed_time  total_elevation_gain            type  \
# 0         4222          4278                  87.0             Run
# 1         4173          4173                   0.0  WeightTraining
# 2         3892          3897                  94.0             Run
# 3         2900          2900                   0.0  WeightTraining
# 4         6262          6708                  66.0             Run
#
#        sport_type  workout_type           id  ... from_accepted_tag pr_count  \
# ...
